# %%
from final_map_climate_to_fire_data import map_climate_to_fire

# %%
map_climate_to_fire(2010)
map_climate_to_fire(2011)
map_climate_to_fire(2012)
map_climate_to_fire(2013)
map_climate_to_fire(2014)
map_climate_to_fire(2015)
map_climate_to_fire(2016)
map_climate_to_fire(2017)
map_climate_to_fire(2018)
map_climate_to_fire(2019)
map_climate_to_fire(2020)
map_climate_to_fire(2021)
map_climate_to_fire(2022)
map_climate_to_fire(2023)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 map_climate_to_fire(2010)
# ----> 2 map_climate_to_fire(2011)
#       3 map_climate_to_fire(2012)
#       4 map_climate_to_fire(2013)
#
# File ~/PycharmProjects/pythonProject/implementation/final-submission/final_map_climate_to_fire_data.py:47, in map_climate_to_fire(year)
#      42         logging.debug(f"{index} Latitude {fire_latitude} longitude {fire_longitude}")
#      43     else:
#      44         new_row = {
#      45             'fire_latitude': fire_latitude,
#      46             'fire_longitude': fire_longitude,
# ---> 47             'climate_latitude': filtered_climate_data.iloc[lon_index,].latitude,
#      48             'climate_longitude': filtered_climate_data.iloc[lon_index,].longitude,
#      49             'daynight': day_night,
#      50             'year': year,
# ...
